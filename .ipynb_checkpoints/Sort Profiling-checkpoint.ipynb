# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

% matplotlib inline

sns.set()

# %%
data_rand = pd.read_csv('results_random.csv')
data_asc  = pd.read_csv('results_ascending.csv')
data_desc = pd.read_csv('results_descending.csv')

# %%
data_rand.head()
# Out:
#    iterations   bubble sort   selection sort   insertion sort   count sort  \
# 0        5000      0.073919         0.032089         0.020019     0.000054
# 1       10000      0.326536         0.124721         0.077928     0.000117
# 2       15000      0.768753         0.279339         0.172057     0.000156
# 3       20000      1.416095         0.497209         0.303348     0.000200
# 4       25000      2.226729         0.778067         0.488329     0.000265
#
#     merge sort   quick sort
# 0     0.001044     0.000657
# 1     0.002300     0.001373
# 2     0.003351     0.002115
# 3     0.004672     0.002910
# 4     0.006054     0.003885

# %% [markdown]
# *Data: Random Element Arrays.*

# %%
data_desc.head()
# Out:
#    iterations   bubble sort   selection sort   insertion sort   count sort  \
# 0        5000      0.087666         0.035099         0.040204     0.000059
# 1       10000      0.347704         0.133745         0.156832     0.000119
# 2       15000      0.793216         0.309584         0.352986     0.000155
# 3       20000      1.394319         0.537604         0.625705     0.000216
# 4       25000      2.168958         0.843250         0.973162     0.000248
#
#     merge sort   quick sort
# 0     0.000756     0.057483
# 1     0.001610     0.227187
# 2     0.002482     0.508374
# 3     0.003193     0.912526
# 4     0.003921     1.419543

# %% [markdown]
# *Data: Decending Order Arrays.*

# %%
data_asc.head()
# Out:
#    iterations   bubble sort   selection sort   insertion sort   count sort  \
# 0        5000      0.034733         0.031542         0.000021     0.000052
# 1       10000      0.138876         0.126400         0.000044     0.000116
# 2       15000      0.308055         0.284760         0.000062     0.000162
# 3       20000      0.548859         0.507867         0.000082     0.000204
# 4       25000      0.854409         0.796591         0.000112     0.000252
#
#     merge sort   quick sort
# 0     0.000735     0.084141
# 1     0.001484     0.314301
# 2     0.002252     0.701974
# 3     0.003102     1.265867
# 4     0.004496     2.235725

# %% [markdown]
# *Data: Ascending Order Arrays.*

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
data_rand.plot(x='iterations', ax=axes[0], title='Random')
data_desc.plot(x='iterations', ax=axes[1], title='Descending')
data_asc.plot (x='iterations', ax=axes[2], title='Ascending')
plt.show()

# %% [markdown]
# *A comparision of iterations vs run-times for all sorts in the above three cases.*

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
data_rand.plot(x='iterations', y=[4,5,6], ax=axes[0], title='Random')
data_desc.plot(x='iterations', y=[4,5], ax=axes[1], title='Descending')
data_asc.plot (x='iterations', y=[4,5], ax=axes[2], title='Ascending')
plt.show()

# %% [markdown]
# *A magnified view of the faster sorting algoriths in each case.*
